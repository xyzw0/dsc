# %% [markdown]
# ---

# %%
print("Hello World")
# Out:
# Hello World

# %%
x= input('enter the number')
y= input('enter the number')

sum = int(x)+int(y)
print('the sum is: ', sum)
# Out:
# enter the number5
# enter the number6
# the sum is:  11
